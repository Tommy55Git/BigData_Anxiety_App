# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /opt/conda/lib/python3.11/site-packages (4.12.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /opt/conda/lib/python3.11/site-packages (from pymongo) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo import MongoClient  # type: ignore

uri = "mongodb+srv://teste:T08m10b033@projeto-bigdata.ydeu01v.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(uri)

db = client['Projeto_BD']
anxiety = db['anxiety']
mental = db['mental_health']

doc = anxiety.find_one()
print("Documento encontrado:", doc)
# Out:
# Documento encontrado: {'_id': ObjectId('67efbd881f66c19422a71348'), 'Age': 46, 'Gender': 'Other', 'Occupation': 'Nurse', 'Sleep Hours': 6.2, 'Physical Activity (hrs/week)': 5.7, 'Caffeine Intake (mg/day)': 200, 'Alcohol Consumption (drinks/week)': 8, 'Smoking': 'Yes', 'Family History of Anxiety': 'Yes', 'Stress Level (1-10)': 1, 'Heart Rate (bpm)': 62, 'Breathing Rate (breaths/min)': 23, 'Sweating Level (1-5)': 2, 'Dizziness': 'Yes', 'Medication': 'No', 'Therapy Sessions (per month)': 2, 'Recent Major Life Event': 'No', 'Diet Quality (1-10)': 8, 'Anxiety Level (1-10)': 3.0}

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark = SparkSession.builder \
    .appName("Projeto") \
    .getOrCreate()

df = spark.read.format("mongodb")\
    .option("spark.mongodb.connection.uri", "mongodb+srv://teste:T08m10b033@projeto-bigdata.ydeu01v.mongodb.net/") \
    .option("spark.mongodb.database", "Projeto_BD")\
    .option("spark.mongodb.collection", "anxiety") \
    .load()

anxiety = df

anxiety.show()
# Out:
# +---+---------------------------------+--------------------+----------------------------+------------------------+-------------------+---------+-------------------------+------+----------------+----------+----------+----------------------------+-----------------------+-----------+-------+-------------------+--------------------+----------------------------+--------------------+
# |Age|Alcohol Consumption (drinks/week)|Anxiety Level (1-10)|Breathing Rate (breaths/min)|Caffeine Intake (mg/day)|Diet Quality (1-10)|Dizziness|Family History of Anxiety|Gender|Heart Rate (bpm)|Medication|Occupation|Physical Activity (hrs/week)|Recent Major Life Event|Sleep Hours|Smoking|Stress Level (1-10)|Sweating Level (1-5)|Therapy Sessions (per month)|                 _id|
# +---+---------------------------------+--------------------+----------------------------+------------------------+-------------------+---------+-------------------------+------+----------------+----------+----------+----------------------------+-----------------------+-----------+-------+-------------------+--------------------+----------------------------+--------------------+
# | 46|                                8|                 3.0|                          23|                     200|                  8|      Yes|                      Yes| Other|              62|        No|     Nurse|                         5.7|                     No|        6.2|    Yes|                  1|                   2|                           2|67efbd881f66c1942...|
# | 53|                                2|                 4.0|                          14|                     235|                  5|       No|                       No|  Male|              84|       Yes|     Other|                         6.5|                    Yes|        6.4|     No|                  9|                   3|                           2|67efbd881f66c1942...|
# | 20|                               14|                 4.0|                          21|                      78|                  2|      Yes|                       No|  Male|             118|        No|    Artist|                         2.5|                    Yes|        7.9|    Yes|                  8|                   5|                           1|67efbd881f66c1942...|
# | 59|                               15|                 4.0|                          28|                     159|                  1|      Yes|                       No|Female|              95|       Yes|   Teacher|                         4.8|                    Yes|        5.1|    Yes|                  5|                   5|                           1|67efbd881f66c1942...|
# | 30|                                4|                 2.0|                          22|                     499|                  9|       No|                       No|  Male|              67|        No|    Doctor|                         5.4|                    Yes|        8.0|     No|                  3|                   3|                           1|67efbd881f66c1942...|
# | 45|                                2|                 3.0|                          12|                     128|                 10|      Yes|                      Yes| Other|              75|       Yes|   Teacher|                         0.1|                    Yes|        7.9|     No|                 10|                   2|                           0|67efbd881f66c1942...|
# | 31|                                8|                 4.0|                          22|                     463|                 10|      Yes|                      Yes| Other|              68|       Yes|  Engineer|                         2.3|                     No|        6.1|    Yes|                  4|                   4|                           1|67efbd881f66c1942...|
# | 56|                               11|                 4.0|                          23|                     103|                  3|      Yes|                       No| Other|              73|       Yes|Freelancer|                         3.5|                    Yes|        6.7|     No|                  5|                   1|                           2|67efbd881f66c1942...|
# | 29|                                9|                 9.0|                          22|                     420|                  4|      Yes|                      Yes|Female|             101|       Yes| Scientist|                         0.3|                     No|        5.0|    Yes|                  9|                   3|                           8|67efbd881f66c1942...|
# | 62|                                6|                 3.0|                          29|                     311|                  2|      Yes|                       No|  Male|              80|        No|    Lawyer|                         5.1|                     No|        4.9|    Yes|                  8|                   1|                           0|67efbd881f66c1942...|
# | 26|                                9|                 4.0|                          27|                     273|                  6|      Yes|                      Yes|Female|              77|       Yes|  Engineer|                         1.4|                     No|        8.5|    Yes|                  6|                   1|                           1|67efbd881f66c1942...|
# | 23|                               12|                 2.0|                          14|                     278|                  8|       No|                       No|  Male|              85|       Yes|   Student|                         1.0|                    Yes|        8.7|    Yes|                  7|                   4|                           2|67efbd881f66c1942...|
# | 53|                                9|                 5.0|                          28|                     443|                  9|       No|                      Yes| Other|              76|        No|    Doctor|                         1.6|                    Yes|        5.9|    Yes|                 10|                   5|                           4|67efbd881f66c1942...|
# | 22|                               16|                 4.0|                          18|                     106|                  7|      Yes|                      Yes|  Male|             114|        No|     Other|                         3.7|                     No|        6.3|     No|                  9|                   5|                           3|67efbd881f66c1942...|
# | 60|                               15|                 2.0|                          15|                     342|                  3|      Yes|                       No|Female|             116|        No|     Nurse|                         0.4|                     No|        7.2|     No|                  6|                   1|                           1|67efbd881f66c1942...|
# | 59|                                0|                 3.0|                          16|                     348|                  7|      Yes|                      Yes| Other|              79|       Yes|    Lawyer|                         3.9|                    Yes|        8.3|     No|                  5|                   1|                           4|67efbd881f66c1942...|
# | 53|                                7|                 4.0|                          24|                     272|                  1|       No|                      Yes|Female|              76|        No|   Teacher|                         1.7|                    Yes|        6.5|     No|                  9|                   1|                           3|67efbd881f66c1942...|
# | 46|                               11|                 1.0|                          28|                     158|                  4|      Yes|                      Yes|  Male|              67|       Yes|  Musician|                         1.8|                     No|        6.4|    Yes|                  1|                   3|                           2|67efbd881f66c1942...|
# | 56|                                8|                 6.0|                          15|                     363|                  1|      Yes|                      Yes|Female|              91|       Yes|    Lawyer|                         4.5|                    Yes|        7.8|     No|                 10|                   3|                           0|67efbd881f66c1942...|
# | 40|                                7|                 2.0|                          14|                     590|                  9|       No|                      Yes|  Male|              83|       Yes|  Engineer|                         1.0|                    Yes|        8.1|     No|                  2|                   1|                           3|67efbd881f66c1942...|
# +---+---------------------------------+--------------------+----------------------------+------------------------+-------------------+---------+-------------------------+------+----------------+----------+----------+----------------------------+-----------------------+-----------+-------+-------------------+--------------------+----------------------------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *

spark1 = SparkSession.builder \
    .appName("Projeto2") \
    .getOrCreate()

df1 = spark1.read.format("mongodb")\
    .option("spark.mongodb.connection.uri", "mongodb+srv://teste:T08m10b033@projeto-bigdata.ydeu01v.mongodb.net/") \
    .option("spark.mongodb.database", "Projeto_BD")\
    .option("spark.mongodb.collection", "mental_health") \
    .load()

mental = df1

mental.show()
# Out:
# +---+---------+----------+--------------+------+---------------+-----------------------+---------------------------+-----------+------------------------+------------+-------------------+--------------------+
# |Age|  Country| Diet Type|Exercise Level|Gender|Happiness Score|Mental Health Condition|Screen Time per Day (Hours)|Sleep Hours|Social Interaction Score|Stress Level|Work Hours per Week|                 _id|
# +---+---------+----------+--------------+------+---------------+-----------------------+---------------------------+-----------+------------------------+------------+-------------------+--------------------+
# | 37|    Japan|Vegetarian|           Low|Female|            9.7|                   None|                        4.7|        7.2|                     9.6|        High|                 43|67efbde21f66c1942...|
# | 49|    Japan| Junk Food|      Moderate|  Male|            6.9|                Anxiety|                        7.2|        6.6|                     5.6|         Low|                 28|67efbde21f66c1942...|
# | 40|   Brazil|  Balanced|      Moderate|  Male|            5.5|                   PTSD|                        5.9|        6.3|                     2.3|         Low|                 41|67efbde21f66c1942...|
# | 48|  Germany|  Balanced|          High|  Male|            5.1|                Anxiety|                        3.9|        2.6|                     1.6|    Moderate|                 52|67efbde21f66c1942...|
# | 19|    India|Vegetarian|          High| Other|            4.1|                Bipolar|                        3.8|        3.8|                     9.1|         Low|                 45|67efbde21f66c1942...|
# | 40|Australia|Vegetarian|      Moderate| Other|            8.0|                   PTSD|                        7.5|        6.1|                     1.4|        High|                 22|67efbde21f66c1942...|
# | 36|    Japan|  Balanced|      Moderate|  Male|            7.8|                Anxiety|                        7.1|        5.1|                     3.8|         Low|                 32|67efbde21f66c1942...|
# | 52|Australia|      Keto|      Moderate|Female|            6.1|             Depression|                        4.3|        4.6|                     3.1|    Moderate|                 32|67efbde21f66c1942...|
# | 38|    India|  Balanced|           Low|Female|            5.0|                Anxiety|                        2.5|        6.0|                     3.4|        High|                 20|67efbde21f66c1942...|
# | 63|Australia|     Vegan|      Moderate| Other|            4.1|                Bipolar|                        4.2|        5.6|                     3.2|    Moderate|                 50|67efbde21f66c1942...|
# | 33|      USA|      Keto|      Moderate|Female|            2.5|                Anxiety|                        7.6|        9.0|                     8.7|    Moderate|                 28|67efbde21f66c1942...|
# | 33|  Germany|     Vegan|           Low|  Male|            4.3|                Bipolar|                        6.9|        6.1|                     4.5|         Low|                 32|67efbde21f66c1942...|
# | 21|   Brazil| Junk Food|      Moderate|Female|            6.9|                   PTSD|                        2.8|        5.1|                     4.1|    Moderate|                 33|67efbde21f66c1942...|
# | 24|    Japan|      Keto|      Moderate|  Male|            7.0|             Depression|                        6.7|        9.9|                     5.1|        High|                 22|67efbde21f66c1942...|
# | 54|      USA| Junk Food|           Low|Female|            2.4|                   None|                        3.3|        8.0|                     2.4|        High|                 45|67efbde21f66c1942...|
# | 39|   Brazil| Junk Food|          High|Female|            3.8|             Depression|                        7.2|        8.9|                     5.8|        High|                 49|67efbde21f66c1942...|
# | 18|Australia|  Balanced|          High|  Male|            8.5|             Depression|                        7.3|        5.2|                     4.5|        High|                 20|67efbde21f66c1942...|
# | 34|Australia|  Balanced|          High|  Male|            8.2|                   None|                        2.0|        6.7|                     5.6|    Moderate|                 43|67efbde21f66c1942...|
# | 28|Australia| Junk Food|      Moderate|  Male|            8.3|                Bipolar|                        2.8|        7.1|                     2.7|    Moderate|                 51|67efbde21f66c1942...|
# | 35|    India|      Keto|      Moderate|Female|            7.5|             Depression|                        3.3|        7.3|                     8.2|        High|                 23|67efbde21f66c1942...|
# +---+---------+----------+--------------+------+---------------+-----------------------+---------------------------+-----------+------------------------+------------+-------------------+--------------------+
# only showing top 20 rows

# %%
import pandas as pd
import json

# Caminhos para os ficheiros
file_path_anxiety = '/data/anxiety.json'
file_path_mental_health = '/data/mental_health.json'

# Carrega os ficheiros JSON
with open(file_path_anxiety, 'r') as f:
    dataset_anxiety = json.load(f)

with open(file_path_mental_health, 'r') as f:
    dataset_mental_health = json.load(f)

# Converte para DataFrame
df_anxiety = pd.DataFrame(dataset_anxiety)
df_mental_health = pd.DataFrame(dataset_mental_health)

# Visualiza as primeiras linhas e estatísticas
print(df_anxiety.head())
print(df_anxiety.describe())

print(df_mental_health.head())
print(df_mental_health.describe())
# Out:
#                                     _id  Age  Gender Occupation  Sleep Hours  \
# 0  {'$oid': '67efbd881f66c19422a71348'}   46   Other      Nurse          6.2
# 1  {'$oid': '67efbd881f66c19422a7134c'}   53    Male      Other          6.4
# 2  {'$oid': '67efbd881f66c19422a7134d'}   20    Male     Artist          7.9
# 3  {'$oid': '67efbd881f66c19422a71350'}   59  Female    Teacher          5.1
# 4  {'$oid': '67efbd881f66c19422a71351'}   30    Male     Doctor          8.0
#
#    Physical Activity (hrs/week)  Caffeine Intake (mg/day)  \
# 0                           5.7                       200
# 1                           6.5                       235
# 2                           2.5                        78
# 3                           4.8                       159
# 4                           5.4                       499
#
#    Alcohol Consumption (drinks/week) Smoking Family History of Anxiety  \
# 0                                  8     Yes                       Yes
# 1                                  2      No                        No
# 2                                 14     Yes                        No
# 3                                 15     Yes                        No
# 4                                  4      No                        No
#
#    Stress Level (1-10)  Heart Rate (bpm)  Breathing Rate (breaths/min)  \
# 0                    1                62                            23
# 1                    9                84                            14
# 2                    8               118                            21
# 3                    5                95                            28
# 4                    3                67                            22
#
#    Sweating Level (1-5) Dizziness Medication  Therapy Sessions (per month)  \
# 0                     2       Yes         No                             2
# 1                     3        No        Yes                             2
# 2                     5       Yes         No                             1
# 3                     5       Yes        Yes                             1
# 4                     3        No         No                             1
#
#   Recent Major Life Event  Diet Quality (1-10)  Anxiety Level (1-10)
# 0                      No                    8                     3
# 1                     Yes                    5                     4
# 2                     Yes                    2                     4
# 3                     Yes                    1                     4
# 4                     Yes                    9                     2
#                 Age   Sleep Hours  Physical Activity (hrs/week)  \
# count  11000.000000  11000.000000                  11000.000000
# mean      40.241727      6.650691                      2.942136
# std       13.236140      1.227509                      1.827825
# min       18.000000      2.300000                      0.000000
# 25%       29.000000      5.900000                      1.500000
# 50%       40.000000      6.700000                      2.800000
# 75%       51.000000      7.500000                      4.200000
# max       64.000000     11.300000                     10.100000
#
#        Caffeine Intake (mg/day)  Alcohol Consumption (drinks/week)  \
# count              11000.000000                       11000.000000
# mean                 286.090000                           9.701636
# std                  144.813157                           5.689713
# min                    0.000000                           0.000000
# 25%                  172.000000                           5.000000
# 50%                  273.000000                          10.000000
# 75%                  382.000000                          15.000000
# max                  599.000000                          19.000000
#
#        Stress Level (1-10)  Heart Rate (bpm)  Breathing Rate (breaths/min)  \
# count         11000.000000      11000.000000                  11000.000000
# mean              5.856364         90.916000                     20.957545
# std               2.927202         17.325721                      5.160107
# min               1.000000         60.000000                     12.000000
# 25%               3.000000         76.000000                     17.000000
# 50%               6.000000         92.000000                     21.000000
# 75%               8.000000        106.000000                     25.000000
# max              10.000000        119.000000                     29.000000
#
#        Sweating Level (1-5)  Therapy Sessions (per month)  \
# count          11000.000000                  11000.000000
# mean               3.080636                      2.427818
# std                1.398877                      2.183106
# min                1.000000                      0.000000
# 25%                2.000000                      1.000000
# 50%                3.000000                      2.000000
# 75%                4.000000                      4.000000
# max                5.000000                     12.000000
#
#        Diet Quality (1-10)  Anxiety Level (1-10)
# count         11000.000000          11000.000000
# mean              5.181818              3.929364
# std               2.895243              2.122533
# min               1.000000              1.000000
# 25%               3.000000              2.000000
# 50%               5.000000              4.000000
# 75%               8.000000              5.000000
# max              10.000000             10.000000
#                                     _id  Country  Age  Gender Exercise Level  \
# 0  {'$oid': '67efbde21f66c19422a73e42'}    Japan   37  Female            Low
# 1  {'$oid': '67efbde21f66c19422a73e46'}    Japan   49    Male       Moderate
# 2  {'$oid': '67efbde21f66c19422a73e4a'}   Brazil   40    Male       Moderate
# 3  {'$oid': '67efbde21f66c19422a73e4c'}  Germany   48    Male           High
# 4  {'$oid': '67efbde21f66c19422a73e52'}    India   19   Other           High
#
#     Diet Type  Sleep Hours Stress Level Mental Health Condition  \
# 0  Vegetarian          7.2         High                    None
# 1   Junk Food          6.6          Low                 Anxiety
# 2    Balanced          6.3          Low                    PTSD
# 3    Balanced          2.6     Moderate                 Anxiety
# 4  Vegetarian          3.8          Low                 Bipolar
#
#    Work Hours per Week  Screen Time per Day (Hours)  Social Interaction Score  \
# 0                   43                          4.7                       9.6
# 1                   28                          7.2                       5.6
# 2                   41                          5.9                       2.3
# 3                   52                          3.9                       1.6
# 4                   45                          3.8                       9.1
#
#    Happiness Score
# 0              9.7
# 1              6.9
# 2              5.5
# 3              5.1
# 4              4.1
#                Age  Sleep Hours  Work Hours per Week  \
# count  3000.000000  3000.000000          3000.000000
# mean     41.229667     6.475933            39.466333
# std      13.428416     1.499866            11.451459
# min      18.000000     1.400000            20.000000
# 25%      30.000000     5.500000            30.000000
# 50%      41.000000     6.500000            39.000000
# 75%      53.000000     7.500000            50.000000
# max      64.000000    11.300000            59.000000
#
#        Screen Time per Day (Hours)  Social Interaction Score  Happiness Score
# count                  3000.000000               3000.000000      3000.000000
# mean                      5.089833                  5.470200         5.395067
# std                       1.747231                  2.563532         2.557601
# min                       2.000000                  1.000000         1.000000
# 25%                       3.600000                  3.300000         3.200000
# 50%                       5.100000                  5.500000         5.400000
# 75%                       6.600000                  7.600000         7.500000
# max                       8.000000                 10.000000        10.000000
